# %% [markdown]
# <img src="images/dask_horizontal.svg" align="right" width="30%">

# %% [markdown]
# # Table of Contents
# * [Distributed, Advanced](#Distributed,-Advanced)
# 	* [Distributed futures](#Distributed-futures)
# 		* [Persist](#Persist)
# 	* [Debugging](#Debugging)

# %% [markdown]
# # Distributed, Advanced

# %% [markdown]
# ## Distributed futures

# %%
# be sure to shut down other kernels running distributed clients
from dask.distributed import Client
c = Client()

# %% [markdown]
# In chapter Distributed, we showed that executing a calculation (created using delayed) with the distributed executor is identical to any other executor. However, we now have access to additional functionality, and control over what data is held in memory.
#
# To begin, the `futures` interface (derived from the built-in `concurrent.futures`) allow map-reduce like functionality. We can submit individual functions for evaluation with one set of inputs, or evaluated over a sequence of inputs with `submit()` and `map()`. Notice that the call returns immediately, giving one or more *futures*, whose status begins as "pending" and later becomes "finished". There is no blocking of the local Python session.

# %% [markdown]
# Here is the simplest example of `submit` in action:

# %%
def inc(x):
    return x+1

fut = c.submit(inc, 1)
fut
# Out:
# <Future: status: pending, key: inc-35dd2c06183a445d212f89c20084190f>

# %% [markdown]
# We can re-execute the following cell as often as we want as a way to poll the status of the future. This could of course be done in a loop, pausing for a short time on each iteration. We could continue with our work, or view a progressbar of work still going on, or force a wait until the future is ready.

# %%
# functions runs on the cluster for a while, we have a local handle to
# that work
fut

# try the preceding cell again, but with
# distributed.diagnostics.progress(fut)
# or
# distributed.client.wait(fut)
# Out:
# <Future: status: finished, type: int, key: inc-35dd2c06183a445d212f89c20084190f>

# %%
# grab the information back - this blocks if fut is not ready
c.gather(fut)
# Out:
# 2

# %% [markdown]
# Here we see an alternative way to execute work on the cluster: when you submit or map with the inputs as futures, the *computation moves to the data* rather than the other way around, and the client, in the local Python session, need never see the intermediate values. This is similar to building the graph using delayed, and indeed, delayed can be used in conjunction with futures. Here we use the delayed object `total` from before.

# %%
# Some trivial work that takes time
# repeated from the Distributed chapter.

from dask import delayed
import time

def inc(x):
    time.sleep(5)
    return x + 1

def dec(x):
    time.sleep(3)
    return x - 1

def add(x, y):
    time.sleep(7)
    return x + y

x = delayed(inc)(1)
y = delayed(dec)(2)
total = delayed(add)(x, y)

# %%
# notice the difference from total.compute()
# notice that this cell completes immediately
fut = c.compute(total)

# %%
c.gather(fut)
# Out:
# 3

# %% [markdown]
# Critically, each futures represents a result held, or being evaluated by the cluster. Thus we can control caching of intermediate values - when a future is no longer referenced, its value is forgotten. For example, although we can explicitly pass data into the cluster using `scatter()`, we normally want to cause the workers to load as much of their own data as possible to avoid excessive communication overhead.
#
# The [full API](http://distributed.readthedocs.io/en/latest/api.html) of the distributed scheduler gives details of interacting with the cluster, which remember, can be on your local machine or possibly on a massive computational resource.

# %% [markdown]
# The futures API offers a work submission style that can easily emulate the map/reduce paradigm (see `c.map()`) that may be familiar to many people. The intermediate results, represented by futures, can be passed to new tasks without having to bring the pull locally from the cluster, and new work can be assigned to work on the output of previous jobs that haven't even begun yet.
#
# Generally, any Dask operation that is executed using `.compute()` can be submitted for asynchronous execution using `c.compute()` instead, and this applies to all collections. Here is an example with the calculation previously seen in the Bag chapter. We have replaced the `.compute()` method there with the distributed client version, so, again, we could continue to submit more work (perhaps based on the result of the calculation), or, in the next cell, follow the progress of the computation. A similar progress-bar appears in the monitoring UI page.

# %%
import dask.bag as db
import os
import json
from dask import distributed
filename = os.path.join('data', 'accounts.*.json.gz')
lines = db.read_text(filename)
js = lines.map(json.loads)

f = c.compute(js.filter(lambda record: record['name'] == 'Alice').pluck('transactions').flatten().pluck('amount').mean())

# %%
# note that progress must be the last line of a cell
# in order to show up
distributed.diagnostics.progress(f)
# Out:
# VBox()

# %%
c.gather(f)
# Out:
# 671.9832130828474

# %% [markdown]
# ### Persist

# %% [markdown]
# Considering which data should be loaded by the workers, as opposed to passed, and which intermediate values to persist in worker memory, will in many cases determine the computation efficiency of a process.
#
# In the example here, we repeat a calculation from the Array chapter - notice that each call to `compute()` is roughly the same speed, because the loading of the data is included every time.

# %%
import h5py
import os
f = h5py.File(os.path.join('data', 'random.hdf5'), mode='r')
dset = f['/x']
import dask.array as da
x = da.from_array(dset, chunks=(1000000,))

# %time x.sum().compute()
# %time x.sum().compute()
# Out:
# CPU times: user 1.56 s, sys: 588 ms, total: 2.15 s
# Wall time: 3.81 s
# CPU times: user 796 ms, sys: 236 ms, total: 1.03 s
# Wall time: 1.51 s
# 9.9999206e+08

# %% [markdown]
# If, instead, we persist the data to RAM up front (this takes a few seconds to complete - we could `wait()` on this process), then further computations will be much faster.

# %%
# changes x from a set of delayed prescritions
# to a set of futures pointing to data in RAM
# See this on the UI dashboard.
x = c.persist(x)

# %%
# %time x.sum().compute()
# %time x.sum().compute()
# Out:
# CPU times: user 2.12 s, sys: 636 ms, total: 2.75 s
# Wall time: 7.64 s
# CPU times: user 1.42 s, sys: 488 ms, total: 1.9 s
# Wall time: 8.8 s
# 9.9999206e+08

# %% [markdown]
# Naturally, persisting every intermediate along the way is a bad idea, because this will tend to fill up all available RAM and make the whole system slow (or break!). The ideal persist point is often at the end of a set of data cleaning steps, when the data is in a form which will get queried often.

# %% [markdown]
# **Exercise**: how is the memory associated with `x` released, once we know we are done with it?

# %% [markdown]
# The worker assumes that when `.compute()` is called, we no longer need the data. Thus, sending a message to RAM to clear that block in memory.

# %% [markdown]
# ## Debugging

# %% [markdown]
# When something goes wrong in a distributed job, it is hard to figure out what the problem was and what to do about it. When a task raises an exception, the exception will show up when that result, or other result that depend upon it, is gathered.
#
# Consider the following delayed calculation to be computed by the cluster. As usual, we get back a future, which the cluster is working on to compute (this happens very slowly for the trivial procedure).

# %%
@delayed
def ratio(a, b):
    return a // b

@delayed
def summation(*a):
    return sum(*a)

ina = [5, 25, 30]
inb = [5, 5, 6]
out = summation([ratio(a, b) for (a, b) in zip(ina, inb)])
f = c.compute(out)
f
# Out:
# <Future: status: pending, key: finalize-581227f9519d0b0f87d3b51d65b08e2c>

# %% [markdown]
# We only get to know what happened when we gather the result (this is also true for `out.compute()`, except we could not have done other stuff in the meantime). For the first set of inputs, it works fine.

# %%
c.gather(f)
# Out:
# 11

# %% [markdown]
# But if we introduce bad input, an exception is raised. The exception happens in `ratio`, but only comes to our attention when calculating `summation`.

# %%
ina = [5, 25, 30]
inb = [5, 0, 6]
out = summation([ratio(a, b) for (a, b) in zip(ina, inb)])
f = c.compute(out)
c.gather(f)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-16-6b5334e4e82f> in <module>()
#       3 out = summation([ratio(a, b) for (a, b) in zip(ina, inb)])
#       4 f = c.compute(out)
# ----> 5 c.gather(f)
#
# ~/anaconda3/envs/dask-tutorial/lib/python3.6/site-packages/distributed/client.py in gather(self, futures, errors, maxsize, direct, asynchronous)
#    1374             return self.sync(self._gather, futures, errors=errors,
#    1375                              direct=direct, local_worker=local_worker,
# -> 1376                              asynchronous=asynchronous)
#    1377
#    1378     @gen.coroutine
#
# ~/anaconda3/envs/dask-tutorial/lib/python3.6/site-packages/distributed/client.py in sync(self, func, *args, **kwargs)
#     546             return future
#     547         else:
# --> 548             return sync(self.loop, func, *args, **kwargs)
#     549
#     550     def __str__(self):
#
# ~/anaconda3/envs/dask-tutorial/lib/python3.6/site-packages/distributed/utils.py in sync(loop, func, *args, **kwargs)
#     239         e.wait(1000000)
#     240     if error[0]:
# --> 241         six.reraise(*error[0])
#     242     else:
#     243         return result[0]
#
# ~/anaconda3/envs/dask-tutorial/lib/python3.6/site-packages/six.py in reraise(tp, value, tb)
#     684         if value.__traceback__ is not tb:
#     685             raise value.with_traceback(tb)
# --> 686         raise value
#     687
#     688 else:
#
# ~/anaconda3/envs/dask-tutorial/lib/python3.6/site-packages/distributed/utils.py in f()
#     227             yield gen.moment
#     228             thread_state.asynchronous = True
# --> 229             result[0] = yield make_coro()
#     230         except Exception as exc:
#     231             logger.exception(exc)
#
# ~/anaconda3/envs/dask-tutorial/lib/python3.6/site-packages/tornado/gen.py in run(self)
#    1053
#    1054                     try:
# -> 1055                         value = future.result()
#    1056                     except Exception:
#    1057                         self.had_exception = True
#
# ~/anaconda3/envs/dask-tutorial/lib/python3.6/site-packages/tornado/concurrent.py in result(self, timeout)
#     236         if self._exc_info is not None:
#     237             try:
# --> 238                 raise_exc_info(self._exc_info)
#     239             finally:
#     240                 self = None
#
# ~/anaconda3/envs/dask-tutorial/lib/python3.6/site-packages/tornado/util.py in raise_exc_info(exc_info)
#
# ~/anaconda3/envs/dask-tutorial/lib/python3.6/site-packages/tornado/gen.py in run(self)
#    1061                     if exc_info is not None:
#    1062                         try:
# -> 1063                             yielded = self.gen.throw(*exc_info)
#    1064                         finally:
#    1065                             # Break up a reference to itself
#
# ~/anaconda3/envs/dask-tutorial/lib/python3.6/site-packages/distributed/client.py in _gather(self, futures, errors, direct, local_worker)
#    1252                             six.reraise(type(exception),
#    1253                                         exception,
# -> 1254                                         traceback)
#    1255                     if errors == 'skip':
#    1256                         bad_keys.add(key)
#
# ~/anaconda3/envs/dask-tutorial/lib/python3.6/site-packages/six.py in reraise(tp, value, tb)
#     683             value = tp()
#     684         if value.__traceback__ is not tb:
# --> 685             raise value.with_traceback(tb)
#     686         raise value
#     687
#
# <ipython-input-14-85efec34ee4d> in ratio()
#       1 @delayed
#       2 def ratio(a, b):
# ----> 3     return a // b
#       4
#       5 @delayed
#
# ZeroDivisionError: integer division or modulo by zero

# %% [markdown]
# The display in this case makes the origin of the exception obvious, but this is not always the case. How should this be debugged, how would we go about finding out the exact conditions that caused the exception?
#
# The first step, of course, is to write well-tested code which makes appropriate assertions about its input and clear warnings and error messages when something goes wrong. This applies to all code.
#
# The most typical thing to do is to execute some portion of the computation in the local thread, so that we can run the Python debugger and query the state of things at the time that the exception happened. Obviously, this cannot be performed on the whole data-set when dealing with Big Data on a cluster, but a suitable sample will probably do even then.

# %%
with dask.set_options(get=dask.async.get_sync):
    # do NOT use c.compute(out) here - we specifically do not
    # want the distributed scheduler
    out.compute()

# %%
debug

# %% [markdown]
# The trouble with this approach is that Dask is meant for the execution of large datasets/computations - you probably can't simply run the whole thing
# in one local thread, else you wouldn't have used Dask in the first place. So the code above should only be used on a small part of the data that also exchibits the error.
# Furthermore, the method will not work when you are dealing with futures (such as `f`, above, or after persisting) instead of delayed-based computations.
#
# As alternative, you can ask the scheduler to analyze your calculation and find the specific sub-task responsible for the error, and pull only it and its dependnecies locally for execution.

# %%
c.recreate_error_locally(f)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-17-727f9a5ca07a> in <module>()
# ----> 1 c.recreate_error_locally(f)
#
# ~/anaconda3/envs/dask-tutorial/lib/python3.6/site-packages/distributed/recreate_exceptions.py in recreate_error_locally(self, future)
#     179         func, args, kwargs = sync(self.client.loop,
#     180                                   self._recreate_error_locally, future)
# --> 181         func(*args, **kwargs)
#
# <ipython-input-14-85efec34ee4d> in ratio(a, b)
#       1 @delayed
#       2 def ratio(a, b):
# ----> 3     return a // b
#       4
#       5 @delayed
#
# ZeroDivisionError: integer division or modulo by zero

# %%
debug
# Out:
# > <ipython-input-15-85efec34ee4d>(3)ratio()
#       1 @delayed
#       2 def ratio(a, b):
# ----> 3     return a // b
#       4
#       5 @delayed
#
# ipdb> ratio(1,0)
# *** NameError: name 'ratio' is not defined
# --KeyboardInterrupt--
# --KeyboardInterrupt--

# %% [markdown]
# Finally, there are errors other than exceptions, when we need to look at the state of the scheduler/workers. In the standard "LocalCluster" we started, we
# have direct access to these.

# %%
c.cluster.scheduler.nbytes
# Out:
# {'inc-35dd2c06183a445d212f89c20084190f': 28,
#  'dec-283e8543-77ca-4f67-be52-6bfe2ec71784': 28,
#  'inc-708c120d-61ed-41a4-8c75-3b0d3a1ef1db': 28,
#  'add-6149e0aa-8b54-454c-9aa7-f9ff4955d22d': 28,
#  'finalize-6dd278c98b7d785d5022217288d8f033': 28,
#  'array-original-defe1c4971d17bb8b1a3bb8c50ac5cf2': 56,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 0)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 1)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 10)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 100)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 101)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 102)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 103)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 104)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 105)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 106)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 107)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 108)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 109)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 11)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 110)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 111)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 112)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 113)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 114)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 115)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 116)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 117)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 118)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 119)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 12)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 120)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 121)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 122)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 123)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 124)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 125)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 126)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 127)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 128)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 129)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 13)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 130)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 131)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 132)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 133)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 134)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 135)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 136)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 137)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 138)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 139)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 14)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 140)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 141)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 142)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 143)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 144)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 145)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 146)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 147)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 148)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 149)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 15)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 150)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 151)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 152)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 153)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 154)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 155)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 156)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 157)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 158)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 159)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 16)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 160)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 161)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 162)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 163)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 164)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 165)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 166)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 167)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 168)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 169)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 17)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 170)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 171)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 172)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 173)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 174)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 175)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 176)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 177)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 178)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 179)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 18)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 180)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 181)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 182)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 183)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 184)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 185)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 186)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 187)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 188)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 189)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 19)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 190)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 191)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 192)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 193)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 194)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 195)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 196)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 197)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 198)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 199)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 2)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 20)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 200)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 201)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 202)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 203)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 204)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 205)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 206)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 207)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 208)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 209)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 21)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 210)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 211)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 212)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 213)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 214)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 215)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 216)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 217)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 218)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 219)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 22)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 220)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 221)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 222)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 223)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 224)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 225)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 226)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 227)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 228)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 229)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 23)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 230)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 231)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 232)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 233)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 234)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 235)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 236)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 237)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 238)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 239)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 24)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 240)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 241)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 242)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 243)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 244)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 245)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 246)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 247)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 248)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 249)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 25)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 250)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 251)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 252)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 253)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 254)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 255)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 256)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 257)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 258)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 259)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 26)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 260)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 261)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 262)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 263)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 264)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 265)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 266)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 267)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 268)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 269)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 27)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 270)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 271)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 272)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 273)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 274)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 275)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 276)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 277)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 278)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 279)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 28)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 280)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 281)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 282)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 283)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 284)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 285)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 286)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 287)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 288)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 289)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 29)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 290)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 291)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 292)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 293)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 294)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 295)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 296)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 297)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 298)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 299)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 3)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 30)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 300)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 301)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 302)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 303)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 304)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 305)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 306)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 307)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 308)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 309)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 31)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 310)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 311)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 312)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 313)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 314)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 315)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 316)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 317)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 318)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 319)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 32)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 320)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 321)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 322)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 323)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 324)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 325)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 326)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 327)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 328)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 329)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 33)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 330)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 331)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 332)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 333)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 334)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 335)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 336)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 337)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 338)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 339)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 34)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 340)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 348)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 342)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 343)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 344)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 341)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 345)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 351)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 355)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 359)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 360)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 347)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 35)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 350)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 352)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 358)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 36)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 369)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 372)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 376)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 356)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 38)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 380)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 39)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 361)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 366)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 37)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 385)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 387)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 388)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 389)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 390)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 397)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 400)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 346)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 349)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 353)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 354)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 357)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 362)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 363)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 364)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 398)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 43)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 438)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 374)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 365)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 402)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 367)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 444)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 403)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 368)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 464)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 370)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 375)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 404)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 407)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 371)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 378)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 408)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 381)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 373)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 467)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 409)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 377)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 495)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 382)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 41)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 379)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 383)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 386)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 496)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 410)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 392)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 384)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 416)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 394)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 395)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 517)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 391)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 42)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 399)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 393)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 536)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 4)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 423)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 396)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 40)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 538)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 401)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 425)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 406)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 405)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 54)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 426)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 412)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 542)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 411)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 427)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 413)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 419)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 549)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 420)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 428)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 414)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 560)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 421)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 430)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 424)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 415)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 584)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 439)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 433)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 44)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 434)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 417)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 585)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 435)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 418)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 59)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 442)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 422)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 436)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 437)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 445)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 446)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 429)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 431)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 432)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 599)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 605)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 449)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 440)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 611)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 443)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 452)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 619)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 459)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 441)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 462)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 640)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 447)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 463)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 448)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 453)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 468)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 455)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 45)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 450)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 644)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 456)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 451)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 469)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 454)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 652)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 457)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 46)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 471)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 472)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 458)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 683)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 460)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 475)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 47)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 7)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 477)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 484)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 470)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 701)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 487)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 488)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 490)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 476)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 479)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 461)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 465)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 491)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 736)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 466)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 492)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 473)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 497)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 750)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 474)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 498)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 48)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 478)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 506)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 480)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 481)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 752)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 780)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 482)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 483)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 507)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 485)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 810)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 49)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 486)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 811)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 489)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 825)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 509)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 493)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 499)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 494)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 84)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 51)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 510)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 511)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 5)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 50)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 843)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 502)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 512)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 500)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 514)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 504)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 501)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 858)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 515)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 519)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 505)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 503)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 508)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 90)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 513)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 520)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 516)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 523)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 907)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 518)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 52)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 527)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 928)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 521)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 526)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 530)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 937)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 529)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 522)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 531)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 524)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 532)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 525)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 53)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 94)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 528)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 533)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 540)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 535)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 534)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 537)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 942)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 544)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 539)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 547)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 545)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 949)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 548)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 541)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 960)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 557)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 961)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 550)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 551)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 543)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 965)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 561)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 546)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 553)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 563)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 979)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 554)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 55)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 988)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 569)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 552)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 993)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 570)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 555)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 556)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 574)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 562)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 558)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 566)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 58)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 582)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 559)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 567)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 568)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 586)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 56)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 564)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 587)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 57)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 565)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 588)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 571)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 575)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 592)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 572)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 594)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 577)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 573)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 576)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 578)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 579)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 596)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 591)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 580)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 598)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 581)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 6)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 600)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 601)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 583)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 603)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 604)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 606)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 589)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 608)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 607)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 590)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 609)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 610)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 593)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 61)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 613)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 614)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 618)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 595)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 621)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 620)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 622)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 597)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 623)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 624)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 60)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 625)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 630)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 602)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 631)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 634)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 627)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 612)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 643)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 615)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 629)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 645)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 616)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 646)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 649)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 654)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 63)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 617)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 632)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 66)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 62)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 664)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 633)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 626)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 628)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 665)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 637)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 667)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 635)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 642)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 648)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 669)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 636)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 638)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 65)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 67)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 639)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 672)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 650)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 64)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 657)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 641)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 674)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 647)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 661)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 651)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 676)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 677)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 679)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 653)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 670)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 681)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 671)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 673)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 655)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 680)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 684)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 656)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 658)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 687)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 682)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 659)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 690)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 692)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 693)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 688)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 660)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 662)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 697)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 691)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 698)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 663)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 695)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 666)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 70)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 668)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 699)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 700)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 675)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 706)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 702)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 678)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 708)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 703)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 705)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 68)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 71)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 707)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 685)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 712)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 709)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 715)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 714)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 686)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 689)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 716)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 72)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 721)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 718)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 730)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 720)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 731)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 69)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 732)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 723)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 694)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 725)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 696)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 704)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 726)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 737)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 710)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 728)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 733)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 741)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 711)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 734)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 713)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 743)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 717)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 746)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 719)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 722)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 749)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 735)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 724)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 727)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 729)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 739)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 75)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 740)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 754)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 742)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 73)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 744)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 756)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 738)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 747)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 759)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 748)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 762)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 74)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 758)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 745)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 763)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 760)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 764)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 761)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 751)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 769)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 753)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 765)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 766)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 767)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 755)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 771)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 77)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 776)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 770)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 757)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 772)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 76)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 78)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 774)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 782)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 768)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 775)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 773)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 784)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 777)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 788)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 781)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 778)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 79)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 783)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 779)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 792)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 790)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 795)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 785)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 791)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 796)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 793)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 786)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 800)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 789)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 794)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 787)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 803)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 80)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 797)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 799)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 801)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 817)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 802)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 798)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 804)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 826)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 808)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 805)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 832)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 8)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 833)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 807)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 812)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 806)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 836)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 815)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 81)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 838)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 816)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 809)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 814)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 813)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 841)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 819)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 818)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 846)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 847)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 82)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 830)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 820)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 848)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 831)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 827)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 850)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 821)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 834)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 828)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 861)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 835)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 840)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 822)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 859)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 829)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 823)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 860)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 842)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 824)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 86)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 863)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 872)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 845)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 865)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 885)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 866)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 83)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 849)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 837)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 886)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 870)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 839)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 852)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 844)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 890)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 896)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 854)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 873)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 85)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 869)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 855)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 871)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 87)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 864)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 851)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 880)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 883)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 877)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 9)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 853)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 884)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 882)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 856)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 887)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 898)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 903)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 905)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 889)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 857)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 918)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 892)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 911)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 941)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 867)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 868)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 862)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 92)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 962)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 893)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 874)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 895)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 897)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 875)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 97)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 985)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 901)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 974)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 878)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 909)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 991)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 913)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 88)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 899)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 917)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 888)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 921)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 89)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 876)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 879)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 906)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 891)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 900)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 925)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 881)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 934)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 902)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 927)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 894)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 91)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 936)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 904)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 931)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 912)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 915)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 910)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 932)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 938)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 908)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 914)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 920)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 940)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 922)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 944)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 919)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 93)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 959)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 947)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 924)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 978)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 948)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 933)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 95)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 926)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 99)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 946)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 916)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 957)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 929)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 923)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 958)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 966)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 930)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 943)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 945)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 970)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 968)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 951)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 935)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 969)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 976)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 955)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 973)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 939)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 977)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 956)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 98)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 963)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 983)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 950)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 984)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 972)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 982)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 952)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 953)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 975)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 990)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 987)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 986)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 954)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 994)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 992)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 989)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 995)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 96)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 964)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 967)": 4000000,
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 971)": 4000000,
#  ...}

# %% [markdown]
# Or we could start ipython processed in remote workers/schedulers to enable examining their states from an interactive session.

# %%
workdict = c.start_ipython_workers()

# %%
w0 = list(workdict.values())[0]

# %%
# %remote w0 worker.keys()
# Out:
# ["('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 611)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 619)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 780)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 787)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 799)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 802)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 804)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 808)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 810)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 811)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 812)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 815)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 816)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 819)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 821)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 825)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 829)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 842)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 843)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 845)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 849)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 852)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 854)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 855)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 858)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 864)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 877)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 882)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 898)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 899)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 906)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 907)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 908)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 914)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 915)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 918)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 919)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 924)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 926)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 928)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 929)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 930)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 934)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 935)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 936)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 937)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 939)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 941)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 942)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 949)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 950)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 952)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 953)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 954)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 960)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 961)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 962)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 964)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 965)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 967)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 971)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 979)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 980)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 981)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 985)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 988)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 991)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 993)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 996)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 997)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 998)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 999)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 275)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 210)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 286)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 255)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 184)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 193)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 215)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 328)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 96)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 174)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 227)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 320)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 12)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 517)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 236)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 538)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 7)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 115)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 752)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 317)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 135)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 284)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 179)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 116)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 266)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 125)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 247)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 542)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 171)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 307)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 121)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 276)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 271)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 133)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 172)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 205)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 335)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 108)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 243)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 186)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 187)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 190)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 167)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 251)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 281)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 221)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 112)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 216)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 101)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 211)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 287)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 188)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 158)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 218)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 219)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 155)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 337)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 277)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 139)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 34)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 560)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 38)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 232)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 701)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 194)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 640)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 332)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 10)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 156)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 199)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 233)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 214)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 467)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 319)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 652)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 297)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 212)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 164)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 206)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 2)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 119)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 82)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 325)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 288)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 279)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 228)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 168)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 283)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 308)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 177)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 220)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 176)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 315)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 173)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 203)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 105)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 239)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 260)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 111)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 313)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 54)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 285)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 142)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 26)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 195)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 230)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 327)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 84)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 152)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 16)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 209)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 189)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 223)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 331)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 43)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 137)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 149)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 159)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 262)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 143)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 140)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 334)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 120)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 750)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 109)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 250)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 280)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 249)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 264)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 235)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 117)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 270)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 296)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 113)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 341)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 17)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 248)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 29)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 273)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 464)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 257)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 124)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 290)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 175)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 213)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 217)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 312)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 129)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 324)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 163)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 229)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 103)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 536)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 122)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 254)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 191)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 303)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 309)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 252)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 295)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 256)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 605)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 644)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 242)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 329)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 314)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 585)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 100)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 268)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 131)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 127)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 31)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 259)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 90)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 234)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 138)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 15)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 322)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 225)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 128)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 330)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 32)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 253)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 267)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 14)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 292)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 356)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 144)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 202)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 302)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 316)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 291)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 584)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 123)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 20)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 180)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 333)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 145)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 27)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 269)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 59)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 198)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 11)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 104)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 197)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 300)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 162)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 22)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 106)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 311)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 102)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 147)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 160)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 110)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 293)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 289)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 196)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 0)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 165)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 222)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 183)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 28)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 161)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 318)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 107)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 39)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 339)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 321)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 141)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 444)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 166)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 192)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 241)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 304)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 549)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 306)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 231)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 19)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 118)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 240)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 150)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 201)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 30)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 224)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 301)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 3)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 130)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 326)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 21)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 282)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 94)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 114)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 237)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 244)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 495)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 148)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 305)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 226)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 380)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 178)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 258)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 204)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 246)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 33)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 18)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 25)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 13)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 323)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 207)",
#  'inc-35dd2c06183a445d212f89c20084190f',
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 272)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 182)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 132)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 294)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 736)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 157)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 683)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 278)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 310)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 398)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 154)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 438)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 181)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 263)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 245)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 170)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 126)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 23)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 151)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 340)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 338)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 599)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 299)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 1)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 185)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 24)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 134)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 336)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 265)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 208)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 496)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 146)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 200)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 136)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 153)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 169)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 238)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 298)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 261)",
#  "('array-defe1c4971d17bb8b1a3bb8c50ac5cf2', 274)"]
